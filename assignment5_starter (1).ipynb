# %%
import numpy as np
import pandas as pd

# %%
# Define the KNN class
class KNN:
    def __init__(self, k=3, distance_metric='euclidean', feature_weights = None):
        self.k = k
        self.distance_metric = distance_metric
        self.feature_weights = feature_weights if feature_weights is not None else np.ones(11)  # Default is equal weights

    def fit(self, X_train, y_train):
        # TODO: Implement the fit method
        self.X_train = X_train
        self.y_train = y_train

    def predict(self, X):
        # TODO: Implement the predict method
        predictions = [self._predict_instance(instance) for instance in X_test]
        return np.array(predictions)

    def compute_distance(self, X1, X2):
        # TODO: Implement distance computation based on self.distance_metric
        # Hint: Use numpy operations for efficient computation

        # Print the shapes of X1 and X2 to debug
        #print(f"X1 shape: {X1.shape}, X2 shape: {X2.shape}")

        # Ensure X1 and X2 are numpy arrays
        X1 = np.array(X1)
        X2 = np.array(X2)

        # Ensure both X1 and X2 have at least 2 dimensions
        if X1.ndim == 1:
            X1 = X1.reshape(1, -1)
        if X2.ndim == 1:
            X2 = X2.reshape(1, -1)

        # Debugging: Print the shapes of X1, X2, and feature weights
        #print(f"X1 shape: {X1.shape}, X2 shape: {X2.shape}, Feature weights shape: {self.feature_weights.shape}")

        # Apply feature weights to X1 and X2
        X1_weighted = X1 * self.feature_weights
        X2_weighted = X2 * self.feature_weights

        if self.distance_metric == 'euclidean':
            return np.sqrt(np.sum((X1_weighted[:, np.newaxis] - X2_weighted) ** 2, axis=2))
        elif self.distance_metric == 'manhattan':
            return np.sum(np.abs(X1_weighted[:, np.newaxis] - X2_weighted), axis=2)

    def predict_proba(self, X_test):
        return np.array([self._predict_instance_proba(instance) for instance in X_test])

    def _predict_instance(self, instance):
        # TODO: Implement instance prediction

        # # Calculate distances from this test instance to all training points
        # distances = [self._distance(instance, x_train) for x_train in self.X_train]
        # # Get the indices of the sorted distances
        # nearest_neighbors_indices = np.argsort(distances)[:self.k]
        # # Get the classes of the K nearest neighbors
        # nearest_neighbors = [self.y_train[i] for i in nearest_neighbors_indices]
        # # Majority vote
        # majority_vote = Counter(nearest_neighbors).most_common(1)[0][0]
        # return majority_vote

        # Step 1: Compute distances from the test instance to all training points
        distances = self.compute_distance(np.array([instance]), self.X_train).flatten()
        # Step 2: Find the indices of the k nearest neighbors
        nearest_neighbors_indices = np.argsort(distances)[:self.k]
        # Step 3: Retrieve the labels of the k nearest neighbors
        nearest_neighbors_labels = self.y_train[nearest_neighbors_indices]
        # Step 4: Perform a majority vote manually
        unique_labels, counts = np.unique(nearest_neighbors_labels, return_counts=True)
        # Step 5: Return the label with the highest count (the majority class)
        return unique_labels[np.argmax(counts)]

    def _predict_instance_proba(self, instance):
      # Step 1: Compute distances from the instance to all training points
      distances = self.compute_distance(np.array([instance]), self.X_train).flatten()

      # Step 2: Find the indices of the k nearest neighbors
      nearest_neighbors_indices = np.argsort(distances)[:self.k]

      # Step 3: Get the labels of the k nearest neighbors
      nearest_neighbors_labels = self.y_train[nearest_neighbors_indices]

      # Step 4: Cast the labels to integer type (in case they are floats)
      nearest_neighbors_labels = nearest_neighbors_labels.astype(int)

      # Step 5: Count the occurrences of each class in the k nearest neighbors
      class_count = np.bincount(nearest_neighbors_labels, minlength=2)

      # Step 5: Calculate probabilities for class 0 and class 1
      prob_class_0 = class_count[0] / self.k  # Probability of class 0 (non-churn)
      prob_class_1 = class_count[1] / self.k  # Probability of class 1 (churn)

      # Step 6: Return the probabilities
      return [prob_class_0, prob_class_1]

# %%
# Define data preprocessing function
def preprocess_data(train_path, test_path):
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)

    # TODO: Implement data preprocessing
    # Handle categorical variables, scale features, etc.

    # Ensure column names are consistent
    train_data.columns = train_data.columns.str.strip().str.lower()
    test_data.columns = test_data.columns.str.strip().str.lower()

    # Drop irrelevant columns
    train_data = train_data.drop(columns=['customerid', 'surname', 'id'], errors='ignore')
    test_data = test_data.drop(columns=['customerid', 'surname', 'id'], errors='ignore')

    ## Handle missing values (fill with mean for numerical columns)
    numerical_cols_train = train_data.select_dtypes(include=np.number).columns
    numerical_cols_test = test_data.select_dtypes(include=np.number).columns

    # Ensure that test_data only uses numerical columns present in both datasets
    common_numerical_cols = [col for col in numerical_cols_test if col in numerical_cols_train]

    # # Handle missing values (fill with mean for numerical columns)
    # train_data.fillna(train_data.mean(), inplace=True)
    # test_data.fillna(test_data.mean(), inplace=True)

    # One-Hot Encoding for 'Geography'
    geography_dummies_train = pd.get_dummies(train_data['geography'], drop_first=True)
    geography_dummies_test = pd.get_dummies(test_data['geography'], drop_first=True)

    train_data = pd.concat([train_data.drop(columns=['geography']), geography_dummies_train], axis=1)
    test_data = pd.concat([test_data.drop(columns=['geography']), geography_dummies_test], axis=1)

    # Label Encoding for 'Gender' (Male -> 0, Female -> 1)
    train_data['gender'] = train_data['gender'].map({'male': 0, 'female': 1})
    test_data['gender'] = test_data['gender'].map({'male': 0, 'female': 1})

    # Convert all boolean columns to numeric (int)
    bool_cols_train = train_data.select_dtypes(include='bool').columns
    bool_cols_test = test_data.select_dtypes(include='bool').columns

    train_data[bool_cols_train] = train_data[bool_cols_train].astype(int)
    test_data[bool_cols_test] = test_data[bool_cols_test].astype(int)

    # Manual Min-Max scaling for numerical columns
    #numerical_columns = [col for col in X_train.columns if col not in ['geography', 'gender', 'hascrcard', 'isactivemember']]

    for col in common_numerical_cols:
        col_min = train_data[col].min()
        col_max = train_data[col].max()
        #print("hello, still works here")

        # Apply scaling for both train and test data
        # Check if the column has zero variance to avoid division by zero
        if col_max - col_min == 0:
            # Handle zero variance columns (e.g., set them to 0)
            train_data[col] = 0
            test_data[col] = 0
        else:
            # Apply scaling for both train and test data
            train_data[col] = (train_data[col] - col_min) / (col_max - col_min)
            test_data[col] = (test_data[col] - col_min) / (col_max - col_min)


    # Separate features and labels
    X_train = train_data.drop(columns=['exited']).values  # Features for training
    y_train = train_data['exited'].values  # Labels for training
    X_test = test_data.values  # Features for testing

    # After preprocessing data in preprocess_data
    print(train_data.dtypes)
    print(test_data.dtypes)


    return X_train, y_train, X_test

# %%
def accuracy_score(y_true, y_pred):
    correct = sum(y_t == y_p for y_t, y_p in zip(y_true, y_pred))
    return correct / len(y_true)

#calculate Area Under Curve of ROC curve
def calculate_roc_auc(y_true, y_pred_probs):
    # Step 1: Sort by predicted probabilities
    sorted_indices = np.argsort(y_pred_probs)[::-1]  # Sort in descending order
    y_true_sorted = y_true[sorted_indices]
    y_pred_probs_sorted = y_pred_probs[sorted_indices]

    # Step 2: Initialize values
    TPRs = [0]  # True Positive Rates
    FPRs = [0]  # False Positive Rates
    thresholds = [1]  # Start with a threshold of 1 (all classified as negative)

    # Initialize counters
    positives = sum(y_true)  # Total number of actual positives (True Positives + False Negatives)
    negatives = len(y_true) - positives  # Total number of actual negatives (True Negatives + False Positives)

    TP = 0  # True Positives
    FP = 0  # False Positives

    # Step 3: Loop through sorted predictions and calculate TPR, FPR
    for i in range(len(y_true_sorted)):
        if y_true_sorted[i] == 1:
            TP += 1  # Correctly classified as positive (True Positive)
        else:
            FP += 1  # Incorrectly classified as positive (False Positive)

        # Compute the TPR and FPR for the current threshold
        TPR = TP / positives  # True Positive Rate (Recall)
        FPR = FP / negatives  # False Positive Rate

        TPRs.append(TPR)
        FPRs.append(FPR)
        thresholds.append(y_pred_probs_sorted[i])

    # Step 4: Compute the AUC using the trapezoidal rule
    # AUC is the area under the ROC curve
    auc = 0.0
    for i in range(1, len(TPRs)):
        auc += (FPRs[i] - FPRs[i - 1]) * (TPRs[i] + TPRs[i - 1]) / 2  # Trapezoidal area

    return np.array(FPRs), np.array(TPRs), auc

# Example usage:
# y_true = np.array([0, 0, 1, 1])
# y_pred_probs = np.array([0.1, 0.4, 0.35, 0.8])

# FPRs, TPRs, auc = calculate_roc_auc(y_true, y_pred_probs)
# print(f"FPR: {FPRs}")
# print(f"TPR: {TPRs}")
# print(f"AUC: {auc}")


# Define cross-validation function
def cross_validate(X, y, knn, n_splits=5):
    # TODO: Implement cross-validation
    # Compute ROC AUC scores

    # Step 1: Shuffle the data to ensure random distribution of folds
    indices = np.arange(len(X))
    np.random.shuffle(indices)
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    # Step 2: Split the data into `n_splits` folds
    fold_size = len(X) // n_splits
    roc_auc_scores = []

    for fold in range(n_splits):
        # Define the validation fold
        start = fold * fold_size
        end = start + fold_size if fold != n_splits - 1 else len(X)

        X_val = X_shuffled[start:end]
        y_val = y_shuffled[start:end]

        # Use the remaining data as the training set
        X_train = np.concatenate([X_shuffled[:start], X_shuffled[end:]], axis=0)
        y_train = np.concatenate([y_shuffled[:start], y_shuffled[end:]], axis=0)

        # Step 3: Train the KNN model
        knn.fit(X_train, y_train)

        # Check the shape of X_val before making predictions
        #print(f"Fold {fold + 1}: X_val shape = {X_val.shape}")

        # Predict probabilities on the validation set
        y_pred_probs = knn.predict_proba(X_val)[:, 1]  # Predict probability of class 1

        # Compute the ROC AUC score for this fold (only store the AUC value)
        _, _, auc = calculate_roc_auc(y_val, y_pred_probs)
        roc_auc_scores.append(auc)  # Store only the AUC score

    # Compute the average ROC AUC score across all folds
    avg_roc_auc = np.mean(roc_auc_scores)

    return avg_roc_auc, roc_auc_scores

    #     # Step 4: Predict probabilities on the validation set
    #     y_pred_probs = knn.predict_proba(X_val)[:, 1]  # Predict probability of class 1

    #     # Step 5: Compute the ROC AUC score for this fold
    #     roc_auc = calculate_roc_auc(y_val, y_pred_probs)
    #     roc_auc_scores.append(roc_auc)

    # # Step 6: Compute the average ROC AUC score across all folds
    # avg_roc_auc = np.mean(roc_auc_scores)

    # return avg_roc_auc, roc_auc_scores

# %%
# Predict results
def save_predictions(knn, X_test, output_file, test_ids):
    predictions = knn.predict(X_test)
    results = pd.DataFrame({'id': test_ids, 'Exited': predictions})
    results.to_csv(output_file, index=False)

#creditscore, geography, gender, age, tenure, balance, numproducts, hascrcard, isactivemember, estimatedsalary
# Define feature weights manually
# Assume 11 features (from your preprocessing step)
feature_weights = np.array([5, 1, 1, 3, 5, 5, 3, 5, 5, 5, 1])  # Adjust these weights as needed
# Load and preprocess data
X, y, X_test = preprocess_data('train.csv', 'test.csv')

# # Create and evaluate model
# knn = KNN(k=5, distance_metric='euclidean')

# # Perform cross-validation
# cv_scores = cross_validate(X, y, knn)
# print("Cross-validation scores:", cv_scores)

# average_roc_auc, roc_auc_scores = cross_validate(X, y, knn)
# print(f"Average ROC AUC across folds: {average_roc_auc}")
# print(f"ROC AUC Scores for each fold: {roc_auc_scores}")

# TODO: hyperparamters tuning

# Initialize variables for hyperparameter tuning
best_k = None
best_distance_metric = None
best_roc_auc = 0

# Define the range of k values and distance metrics to try
k_values = range(10, 100)  # k values to test
distance_metrics = ['euclidean', 'manhattan']

# TODO: Perform cross-validation and hyperparameter tuning
for k in k_values:
    for metric in distance_metrics:
        # Create a KNN model with the current hyperparameters
        knn = KNN(k=k, distance_metric=metric, feature_weights=feature_weights)

        # Perform cross-validation to evaluate the model
        average_roc_auc, roc_auc_scores = cross_validate(X, y, knn, n_splits=5)

        #accuracy = accuracy_score(y, knn.predict(X))

        # Print the current hyperparameters and ROC AUC score
        print(f"k: {k}, Distance Metric: {metric}, Average ROC AUC: {average_roc_auc}")

        # Check if this is the best ROC AUC score so far
        if average_roc_auc > best_roc_auc:
            best_roc_auc = average_roc_auc
            best_k = k
            best_distance_metric = metric

# Print the best hyperparameters found
print(f"Best k: {best_k}, Best Distance Metric: {best_distance_metric}, Best ROC AUC: {best_roc_auc}")

# TODO: Train the model on the full dataset with the best hyperparameters
knn = KNN(k=best_k, distance_metric=best_distance_metric)
knn.fit(X, y)

# Make predictions on the test set
test_predictions = knn.predict(X_test)

test_data = pd.read_csv('test.csv')
test_ids = test_data['id']

# Save test predictions
save_predictions(knn, X_test, 'knn_submission.csv', test_ids)
pd.DataFrame({'id': pd.read_csv('test.csv')['id'], 'Exited': test_predictions}).to_csv('submissions.csv', index=False)
# Out:
# creditscore        float64
# gender             float64
# age                float64
# tenure             float64
# balance            float64
# numofproducts      float64
# hascrcard          float64
# isactivemember     float64
# estimatedsalary    float64
# exited             float64
# Germany              int64
# Spain                int64
# dtype: object
# creditscore        float64
# gender             float64
# age                float64
# tenure             float64
# balance            float64
# numofproducts      float64
# hascrcard          float64
# isactivemember     float64
# estimatedsalary    float64
# Germany              int64
# Spain                int64
# dtype: object
# k: 10, Distance Metric: euclidean, Average ROC AUC: 0.5029388575892549
# k: 10, Distance Metric: manhattan, Average ROC AUC: 0.5072146314803005
# k: 11, Distance Metric: euclidean, Average ROC AUC: 0.49771006104499954
# k: 11, Distance Metric: manhattan, Average ROC AUC: 0.495642067605712
# k: 12, Distance Metric: euclidean, Average ROC AUC: 0.49960590938021926
# k: 12, Distance Metric: manhattan, Average ROC AUC: 0.4939920742721897
# k: 13, Distance Metric: euclidean, Average ROC AUC: 0.5013499311342775
# k: 13, Distance Metric: manhattan, Average ROC AUC: 0.4912838942228047
# k: 14, Distance Metric: euclidean, Average ROC AUC: 0.49883917197987976
# k: 14, Distance Metric: manhattan, Average ROC AUC: 0.4989672597549809
# k: 15, Distance Metric: euclidean, Average ROC AUC: 0.5013067233939669
# k: 15, Distance Metric: manhattan, Average ROC AUC: 0.5000304244958589
# k: 16, Distance Metric: euclidean, Average ROC AUC: 0.49738975911144656
# k: 16, Distance Metric: manhattan, Average ROC AUC: 0.48870023801852264
# k: 17, Distance Metric: euclidean, Average ROC AUC: 0.5063999667804249
# k: 17, Distance Metric: manhattan, Average ROC AUC: 0.5106727820174515
# k: 18, Distance Metric: euclidean, Average ROC AUC: 0.4965392138719764
# k: 18, Distance Metric: manhattan, Average ROC AUC: 0.5101570282301913
# k: 19, Distance Metric: euclidean, Average ROC AUC: 0.5048703154205308
# k: 19, Distance Metric: manhattan, Average ROC AUC: 0.4950734743703432
# k: 20, Distance Metric: euclidean, Average ROC AUC: 0.49638947808484285
# k: 20, Distance Metric: manhattan, Average ROC AUC: 0.49746118187199573
# k: 21, Distance Metric: euclidean, Average ROC AUC: 0.514745824291978
# k: 21, Distance Metric: manhattan, Average ROC AUC: 0.49091552354318485
# k: 22, Distance Metric: euclidean, Average ROC AUC: 0.5007737768404494
# k: 22, Distance Metric: manhattan, Average ROC AUC: 0.49320703659258996
# k: 23, Distance Metric: euclidean, Average ROC AUC: 0.492419407707153
# k: 23, Distance Metric: manhattan, Average ROC AUC: 0.49253739228970456
# k: 24, Distance Metric: euclidean, Average ROC AUC: 0.49868842632990457
# k: 24, Distance Metric: manhattan, Average ROC AUC: 0.492141810534101
# k: 25, Distance Metric: euclidean, Average ROC AUC: 0.5054183612998696
# k: 25, Distance Metric: manhattan, Average ROC AUC: 0.48197768799073604
# k: 26, Distance Metric: euclidean, Average ROC AUC: 0.5096865256986751
# k: 26, Distance Metric: manhattan, Average ROC AUC: 0.5009732891007956
# k: 27, Distance Metric: euclidean, Average ROC AUC: 0.502517238104792
# k: 27, Distance Metric: manhattan, Average ROC AUC: 0.5040913665569416
# k: 28, Distance Metric: euclidean, Average ROC AUC: 0.49052218966869987
# k: 28, Distance Metric: manhattan, Average ROC AUC: 0.4959894017682931
# k: 29, Distance Metric: euclidean, Average ROC AUC: 0.5070907733028649
# k: 29, Distance Metric: manhattan, Average ROC AUC: 0.48941182090526353
# k: 30, Distance Metric: euclidean, Average ROC AUC: 0.5002239205939965
# k: 30, Distance Metric: manhattan, Average ROC AUC: 0.49685968183293683
# k: 31, Distance Metric: euclidean, Average ROC AUC: 0.5070847793716601
# k: 31, Distance Metric: manhattan, Average ROC AUC: 0.49844350580904956
# k: 32, Distance Metric: euclidean, Average ROC AUC: 0.4994435895523434
# k: 32, Distance Metric: manhattan, Average ROC AUC: 0.49974670753605877
# k: 33, Distance Metric: euclidean, Average ROC AUC: 0.4979721788927418
# k: 33, Distance Metric: manhattan, Average ROC AUC: 0.5048668286177734
# k: 34, Distance Metric: euclidean, Average ROC AUC: 0.5001439362591193
# k: 34, Distance Metric: manhattan, Average ROC AUC: 0.4999410012375791
# k: 35, Distance Metric: euclidean, Average ROC AUC: 0.4904381081490133
# k: 35, Distance Metric: manhattan, Average ROC AUC: 0.497607468315974
# k: 36, Distance Metric: euclidean, Average ROC AUC: 0.4975502261106108
# k: 36, Distance Metric: manhattan, Average ROC AUC: 0.5006632909374218
# k: 37, Distance Metric: euclidean, Average ROC AUC: 0.5035108424193391
# k: 37, Distance Metric: manhattan, Average ROC AUC: 0.4949897773168249
# k: 38, Distance Metric: euclidean, Average ROC AUC: 0.5041240275931367
# k: 38, Distance Metric: manhattan, Average ROC AUC: 0.5044945762490034
# k: 39, Distance Metric: euclidean, Average ROC AUC: 0.49769421077762743
# k: 39, Distance Metric: manhattan, Average ROC AUC: 0.49859839497834735
# k: 40, Distance Metric: euclidean, Average ROC AUC: 0.5013365472006358
# k: 40, Distance Metric: manhattan, Average ROC AUC: 0.5075061588718242
# k: 41, Distance Metric: euclidean, Average ROC AUC: 0.4994266055566047
# k: 41, Distance Metric: manhattan, Average ROC AUC: 0.4894056778026517
# k: 42, Distance Metric: euclidean, Average ROC AUC: 0.49703486297141364
# k: 42, Distance Metric: manhattan, Average ROC AUC: 0.5039283750431373
# k: 43, Distance Metric: euclidean, Average ROC AUC: 0.5040512802017307
# k: 43, Distance Metric: manhattan, Average ROC AUC: 0.48768159832110863
# k: 44, Distance Metric: euclidean, Average ROC AUC: 0.5056095942705527
# k: 44, Distance Metric: manhattan, Average ROC AUC: 0.5044224126069681
# k: 45, Distance Metric: euclidean, Average ROC AUC: 0.4943140452322391
# k: 45, Distance Metric: manhattan, Average ROC AUC: 0.4969795442242596
# k: 46, Distance Metric: euclidean, Average ROC AUC: 0.5072422152329861
# k: 46, Distance Metric: manhattan, Average ROC AUC: 0.49729485492659287
# k: 47, Distance Metric: euclidean, Average ROC AUC: 0.5046254927124509
# k: 47, Distance Metric: manhattan, Average ROC AUC: 0.510637311438715
# k: 48, Distance Metric: euclidean, Average ROC AUC: 0.4999490464630843
# k: 48, Distance Metric: manhattan, Average ROC AUC: 0.5028324723129198
# k: 49, Distance Metric: euclidean, Average ROC AUC: 0.4950123038248358
# k: 49, Distance Metric: manhattan, Average ROC AUC: 0.49828630752633496
# k: 50, Distance Metric: euclidean, Average ROC AUC: 0.4940754692189865
# k: 50, Distance Metric: manhattan, Average ROC AUC: 0.49892469161572023
# k: 51, Distance Metric: euclidean, Average ROC AUC: 0.5034986055395777
# k: 51, Distance Metric: manhattan, Average ROC AUC: 0.5058165571847488
# k: 52, Distance Metric: euclidean, Average ROC AUC: 0.5052255365965153
# k: 52, Distance Metric: manhattan, Average ROC AUC: 0.5093415127714487
# k: 53, Distance Metric: euclidean, Average ROC AUC: 0.5069295123609687
# k: 53, Distance Metric: manhattan, Average ROC AUC: 0.4960555271989244
# k: 54, Distance Metric: euclidean, Average ROC AUC: 0.5033027711287863
# k: 54, Distance Metric: manhattan, Average ROC AUC: 0.5009758682786638
# k: 55, Distance Metric: euclidean, Average ROC AUC: 0.5001390386949852
# k: 55, Distance Metric: manhattan, Average ROC AUC: 0.5000245547136246
# k: 56, Distance Metric: euclidean, Average ROC AUC: 0.5120919861801445
# k: 56, Distance Metric: manhattan, Average ROC AUC: 0.5106286725944682
# k: 57, Distance Metric: euclidean, Average ROC AUC: 0.5028895779712494
# k: 57, Distance Metric: manhattan, Average ROC AUC: 0.49590147467790224
# k: 58, Distance Metric: euclidean, Average ROC AUC: 0.5013976224126233
# k: 58, Distance Metric: manhattan, Average ROC AUC: 0.49611674395982036
# k: 59, Distance Metric: euclidean, Average ROC AUC: 0.49857987068626974
# k: 59, Distance Metric: manhattan, Average ROC AUC: 0.5025119329460426
# k: 60, Distance Metric: euclidean, Average ROC AUC: 0.48254847493898473
# k: 60, Distance Metric: manhattan, Average ROC AUC: 0.4874609487255329
# k: 61, Distance Metric: euclidean, Average ROC AUC: 0.50665990107237
# k: 61, Distance Metric: manhattan, Average ROC AUC: 0.504865124096127
# k: 62, Distance Metric: euclidean, Average ROC AUC: 0.4926920133772376
# k: 62, Distance Metric: manhattan, Average ROC AUC: 0.5045880571344057
# k: 63, Distance Metric: euclidean, Average ROC AUC: 0.4991192837272376
# k: 63, Distance Metric: manhattan, Average ROC AUC: 0.49863423579144384
# k: 64, Distance Metric: euclidean, Average ROC AUC: 0.5023316309513761
# k: 64, Distance Metric: manhattan, Average ROC AUC: 0.49455500039818234
# k: 65, Distance Metric: euclidean, Average ROC AUC: 0.4992781005210136
# k: 65, Distance Metric: manhattan, Average ROC AUC: 0.4945610260563325
# k: 66, Distance Metric: euclidean, Average ROC AUC: 0.5032998509000552
# k: 66, Distance Metric: manhattan, Average ROC AUC: 0.5010559992167268
# k: 67, Distance Metric: euclidean, Average ROC AUC: 0.4998629303122219
# k: 67, Distance Metric: manhattan, Average ROC AUC: 0.5054769997750367
# k: 68, Distance Metric: euclidean, Average ROC AUC: 0.4995489641282174
# k: 68, Distance Metric: manhattan, Average ROC AUC: 0.4929436865587582
# k: 69, Distance Metric: euclidean, Average ROC AUC: 0.4884011453605421
# k: 69, Distance Metric: manhattan, Average ROC AUC: 0.49970088489278125
# k: 70, Distance Metric: euclidean, Average ROC AUC: 0.5062398360087561
# k: 70, Distance Metric: manhattan, Average ROC AUC: 0.511099698232352
# k: 71, Distance Metric: euclidean, Average ROC AUC: 0.5034630620157127
# k: 71, Distance Metric: manhattan, Average ROC AUC: 0.5047483106737616
# k: 72, Distance Metric: euclidean, Average ROC AUC: 0.5109908531992781
# k: 72, Distance Metric: manhattan, Average ROC AUC: 0.5012790950170067
# k: 73, Distance Metric: euclidean, Average ROC AUC: 0.5079487488099851
# k: 73, Distance Metric: manhattan, Average ROC AUC: 0.4893676278613805
# k: 74, Distance Metric: euclidean, Average ROC AUC: 0.4962897551487406
# k: 74, Distance Metric: manhattan, Average ROC AUC: 0.5001697768032642
# k: 75, Distance Metric: euclidean, Average ROC AUC: 0.4921911377284645
# k: 75, Distance Metric: manhattan, Average ROC AUC: 0.4837047537747253
# k: 76, Distance Metric: euclidean, Average ROC AUC: 0.503433299323504
# k: 76, Distance Metric: manhattan, Average ROC AUC: 0.5028340865792227
# k: 77, Distance Metric: euclidean, Average ROC AUC: 0.5083971063164464
# k: 77, Distance Metric: manhattan, Average ROC AUC: 0.5052599564439302
# k: 78, Distance Metric: euclidean, Average ROC AUC: 0.5031326675736378
# k: 78, Distance Metric: manhattan, Average ROC AUC: 0.5002342261351498
# k: 79, Distance Metric: euclidean, Average ROC AUC: 0.5072848436623005
# k: 79, Distance Metric: manhattan, Average ROC AUC: 0.499060175041157
# k: 80, Distance Metric: euclidean, Average ROC AUC: 0.500017633651489
# k: 80, Distance Metric: manhattan, Average ROC AUC: 0.49566637563596994
# k: 81, Distance Metric: euclidean, Average ROC AUC: 0.5034293173872884
# k: 81, Distance Metric: manhattan, Average ROC AUC: 0.49973036126409187
# k: 82, Distance Metric: euclidean, Average ROC AUC: 0.4968668477255097
# k: 82, Distance Metric: manhattan, Average ROC AUC: 0.4928521061020968
# k: 83, Distance Metric: euclidean, Average ROC AUC: 0.4913528232352816
# k: 83, Distance Metric: manhattan, Average ROC AUC: 0.49931738275545756
# k: 84, Distance Metric: euclidean, Average ROC AUC: 0.4906018146073953
# k: 84, Distance Metric: manhattan, Average ROC AUC: 0.5033430068398201
# k: 85, Distance Metric: euclidean, Average ROC AUC: 0.4940523522449391
# k: 85, Distance Metric: manhattan, Average ROC AUC: 0.5007781772029307
# k: 86, Distance Metric: euclidean, Average ROC AUC: 0.49288635168462713
# k: 86, Distance Metric: manhattan, Average ROC AUC: 0.5009601147528541
# k: 87, Distance Metric: euclidean, Average ROC AUC: 0.5055819683076794
# k: 87, Distance Metric: manhattan, Average ROC AUC: 0.5001577235253197
# k: 88, Distance Metric: euclidean, Average ROC AUC: 0.4888861669315442
# k: 88, Distance Metric: manhattan, Average ROC AUC: 0.49591077745071016
# k: 89, Distance Metric: euclidean, Average ROC AUC: 0.5031602110261091
# k: 89, Distance Metric: manhattan, Average ROC AUC: 0.5004434738310566
# k: 90, Distance Metric: euclidean, Average ROC AUC: 0.4930295217519232
# k: 90, Distance Metric: manhattan, Average ROC AUC: 0.50471293929309
# k: 91, Distance Metric: euclidean, Average ROC AUC: 0.5001802620817888
# k: 91, Distance Metric: manhattan, Average ROC AUC: 0.48631984575898646
# k: 92, Distance Metric: euclidean, Average ROC AUC: 0.49279460603257325
# k: 92, Distance Metric: manhattan, Average ROC AUC: 0.4976885151050704
# k: 93, Distance Metric: euclidean, Average ROC AUC: 0.5041875920644371
# k: 93, Distance Metric: manhattan, Average ROC AUC: 0.5083086238515919
# k: 94, Distance Metric: euclidean, Average ROC AUC: 0.507890748904158
# k: 94, Distance Metric: manhattan, Average ROC AUC: 0.5037724180150992
# k: 95, Distance Metric: euclidean, Average ROC AUC: 0.4990370757171091
# k: 95, Distance Metric: manhattan, Average ROC AUC: 0.5059530718202413
# k: 96, Distance Metric: euclidean, Average ROC AUC: 0.5020354908185616
# k: 96, Distance Metric: manhattan, Average ROC AUC: 0.49672208015801206
# k: 97, Distance Metric: euclidean, Average ROC AUC: 0.49478769454019655
# k: 97, Distance Metric: manhattan, Average ROC AUC: 0.4974385159419274
# k: 98, Distance Metric: euclidean, Average ROC AUC: 0.5025249771421544
# k: 98, Distance Metric: manhattan, Average ROC AUC: 0.5045970385221539
# k: 99, Distance Metric: euclidean, Average ROC AUC: 0.5015207192520361
# k: 99, Distance Metric: manhattan, Average ROC AUC: 0.4956969195088998
# Best k: 21, Best Distance Metric: euclidean, Best ROC AUC: 0.514745824291978
